# %%
path = '/Users/wenshuiluo/LEAP-Group/experiments/毕设/Results/cifar100/03-01'
import matplotlib.pyplot as plt
import os
# %matplotlib inline
import numpy as np
import json
from utils.utils import list_dir, list_files
from collections import namedtuple
param = ('lr','openset_ratio','closeset_ratio','noise_type','tau_clean', 'threshold')
param = namedtuple('param', param)
dir_list = list_dir(path)
plot_list=[]
json_list = []
for idx, dir in enumerate(dir_list):
    txt_files = list_files(os.path.join(path, dir), suffix = '.txt', prefix = True)
    json_files = list_files(os.path.join(path, dir), suffix='.json', prefix = True)
    plot_list.append(txt_files[1])
    json_list.append(json_files[0])
for file in plot_list:
    print(file)
print()
kwmap={}

for index, json_file in enumerate(json_list):
    with open(json_file) as file:
        kw = json.load(file)
        kwmap[index] = param(kw['lr'],kw['openset_ratio'],kw['closeset_ratio'],kw['noise_type'], kw['tau_clean'], kw['threshold'])
        
sel = []
for key,value in kwmap.items():
    if value.openset_ratio == 0.2 and value.closeset_ratio == 0.4:
        print(key)
        sel.append(key)
for item in sel:
    print(kwmap[item])
data = {}

for index, file in enumerate(plot_list):
    num = 300
    with open(file) as f:
        lines = f.readlines()
    # if len(lines)<100:
    #     continue
    if index not in sel:
        continue
    x_axis = list(np.arange(1, len(lines[:num]) + 1))
    result = [float(line.split('|')[3].strip().split()[-1]) for line in lines[:num]]
    mean = np.array(result)[10:].mean()
    print(mean)
    # plt.figure(figsize=(8,6))
    # plt.plot(x_axis, result)
    # plt.title(kwmap[index])
# Out:
# /Users/wenshuiluo/LEAP-Group/experiments/毕设/Results/cifar100/03-01/cnn-symmetric_closeset0.2_openset0.0-S2S-20220301_080100-bestAcc_62.2400/log.txt
# /Users/wenshuiluo/LEAP-Group/experiments/毕设/Results/cifar100/03-01/cnn-pairflip_closeset0.4_openset0.2-S2S-20220303_082421-bestAcc_46.8750/log.txt
# /Users/wenshuiluo/LEAP-Group/experiments/毕设/Results/cifar100/03-01/cnn-symmetric_closeset0.8_openset0.2-S2S-20220302_131103-bestAcc_31.5625/log.txt
# /Users/wenshuiluo/LEAP-Group/experiments/毕设/Results/cifar100/03-01/wideresnet-pairflip_closeset0.4_openset0.2-S2S-20220301_155621-bestAcc_40.2125/log.txt
# /Users/wenshuiluo/LEAP-Group/experiments/毕设/Results/cifar100/03-01/cnn-pairflip_closeset0.4_openset0.2-S2S-20220302_165340-bestAcc_47.6625/log.txt
# /Users/wenshuiluo/LEAP-Group/experiments/毕设/Results/cifar100/03-01/cnn-symmetric_closeset0.5_openset0.2-S2S-20220303_002529-bestAcc_45.7125/log.txt
# ...

# %% [markdown]
# ## 绘制精度曲线

# %%
path = '/Users/wenshuiluo/LEAP-Group/experiments/毕设/Results/cifar100/03-01'
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
fonts = FontProperties(fname = "/Library/Fonts/Arial Unicode.ttf")
plt.rcParams["font.family"] = 'Arial Unicode MS'
plt.rcParams['axes.unicode_minus']=False
plt.rcParams.update({'font.size': 25})
import os
# %matplotlib inline
import numpy as np
import json
from utils.utils import list_dir, list_files
from collections import namedtuple
param = ('lr','openset_ratio','closeset_ratio','noise_type','tau_clean', 'threshold')
param = namedtuple('param', param)
dir_list = list_dir(path)
plot_list=[]
json_list = []
for idx, dir in enumerate(dir_list):
    txt_files = list_files(os.path.join(path, dir), suffix = '.txt', prefix = True)
    json_files = list_files(os.path.join(path, dir), suffix='.json', prefix = True)
    plot_list.append(txt_files[1])
    json_list.append(json_files[0])
for file in plot_list:
    print(file)
plot_list=np.array(plot_list)
print()
kwmap={}

for index, json_file in enumerate(json_list):
    with open(json_file) as file:
        kw = json.load(file)
        kwmap[index] = param(kw['lr'],kw['openset_ratio'],kw['closeset_ratio'],kw['noise_type'], kw['tau_clean'], kw['threshold'])
        
sel = [0, 8, 11, 7]
for item in sel:
    print(kwmap[item])

sel_2=[12, 4, 2, 9]
for item in sel_2:
    print(kwmap[item])

plt.figure(figsize=(20,6), dpi=280)

plt.subplot(1,2,1)
plt.grid(linewidth=0.4)
plt.xlabel('训练周期',fontsize=16)
plt.ylabel('分类准确率',fontsize=16)
labels = {
    0:'Symmetric openset_ratio=0%, closeset_ratio=20%',
    8:'Symmetric openset_ratio=0%, closeset_ratio=50%',
    11:'Symmetric openset_ratio=0%, closeset_ratio=80%',   
    7:'Asymmetric openset_ratio=0%, closeset_ratio=40%',
          }
tuple_label = tuple(labels.values())
for index, file in enumerate(plot_list[sel]):
    num = 300
    with open(file) as f:
        lines = f.readlines()
    if len(lines)<100:
        continue

    x_axis = list(np.arange(1, len(lines[:num]) + 1))
    result = [float(line.split('|')[3].strip().split()[-1]) for line in lines[:num]]
    result = np.array(result)
    mean = result[10:].mean()
    print(mean)
    
    plt.plot(x_axis, result, linewidth=2.0)
plt.title('闭集标签噪声',fontsize=20)
plt.legend(tuple_label,fontsize=12)
plt.subplot(1,2,2)
plt.grid(linewidth=0.4)
plt.xlabel('训练周期',fontsize=16)
plt.ylabel('分类准确率',fontsize=16)

labels = {
    12:'Symmetric openset_ratio=2%, closeset_ratio=20%',
    9:'Symmetric openset_ratio=0%, closeset_ratio=50%',     
    2:'Symmetric openset_ratio=0%, closeset_ratio=80%',
    4:'Asymmetric openset_ratio=0%, closeset_ratio=40%'
          }
tuple_label = tuple(labels.values())
for index, file in enumerate(plot_list[sel_2]):
    num = 300
    with open(file) as f:
        lines = f.readlines()
    if len(lines)<100:
        continue
    # if index not in sel_2:
    #     continue
    x_axis = list(np.arange(1, len(lines[:num]) + 1))
    result = [float(line.split('|')[3].strip().split()[-1]) for line in lines[:num]]
    result = np.array(result)
    mean = result[10:].mean()
    print(mean)
    
    plt.plot(x_axis, result, linewidth=2.0)
plt.title('混合开闭集标签噪声',fontsize=20)
plt.legend(tuple_label,fontsize=12)
# Out:
# /Users/wenshuiluo/LEAP-Group/experiments/毕设/Results/cifar100/03-01/cnn-symmetric_closeset0.2_openset0.0-S2S-20220301_080100-bestAcc_62.2400/log.txt
# /Users/wenshuiluo/LEAP-Group/experiments/毕设/Results/cifar100/03-01/cnn-pairflip_closeset0.4_openset0.2-S2S-20220303_082421-bestAcc_46.8750/log.txt
# /Users/wenshuiluo/LEAP-Group/experiments/毕设/Results/cifar100/03-01/cnn-symmetric_closeset0.8_openset0.2-S2S-20220302_131103-bestAcc_31.5625/log.txt
# /Users/wenshuiluo/LEAP-Group/experiments/毕设/Results/cifar100/03-01/wideresnet-pairflip_closeset0.4_openset0.2-S2S-20220301_155621-bestAcc_40.2125/log.txt
# /Users/wenshuiluo/LEAP-Group/experiments/毕设/Results/cifar100/03-01/cnn-pairflip_closeset0.4_openset0.2-S2S-20220302_165340-bestAcc_47.6625/log.txt
# /Users/wenshuiluo/LEAP-Group/experiments/毕设/Results/cifar100/03-01/cnn-symmetric_closeset0.5_openset0.2-S2S-20220303_002529-bestAcc_45.7125/log.txt
# ...

# %% [markdown]
# ## ablation study

# %%
path = '/Users/wenshuiluo/LEAP-Group/毕业设计/ablation/去除损失/Results/cifar100'
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
fonts = FontProperties(fname = "/Library/Fonts/Arial Unicode.ttf")
plt.rcParams["font.family"] = 'Arial Unicode MS'
plt.rcParams['axes.unicode_minus']=False
plt.rcParams.update({'font.size': 25})
import os
# %matplotlib inline
import numpy as np
import json
from utils.utils import list_dir, list_files
from collections import namedtuple
param = ('lr','openset_ratio','closeset_ratio','noise_type','tau_clean', 'threshold')
param = namedtuple('param', param)
dir_list = list_dir(path)
plot_list=[]
json_list = []
for idx, dir in enumerate(dir_list):
    txt_files = list_files(os.path.join(path, dir), suffix = '.txt', prefix = True)
    json_files = list_files(os.path.join(path, dir), suffix='.json', prefix = True)
    plot_list.append(txt_files[1])
    json_list.append(json_files[0])
# plot_list=np.array(plot_list)[[0,1,3,4]]
for index, file in enumerate(plot_list):
    num = 300
    print(file)
    # json_f = json.load(json_list[index])
    with open(json_list[index]) as f:
        json_f = json.load(f)
        print(json_f)
    print(json_f)
    with open(file) as f:
        lines = f.readlines()
    result = np.array([float(line.split('|')[3].strip().split()[-1]) for line in lines[:num]])
    x_axis = list(np.arange(1, len(lines[:num]) + 1))
    plt.figure()
    plt.plot(x_axis, result, linewidth=2.0)
    print(result[10:].mean())
print()
kwmap={}
# Out:
# /Users/wenshuiluo/LEAP-Group/毕业设计/ablation/去除损失/Results/cifar100/cnn-symmetric_closeset0.2_openset0.2-S2S-20220506_024046-bestAcc_60.0750/log.txt
# {'database': 'Datasets', 'dataset': 'cifar100', 'n_classes': 100, 'rescale_size': 32, 'crop_size': 32, 'num_workers': 8, 'steps': 512, 'net': 'cnn', 'opt': 'adam', 'batch_size': 64, 'lr': 0.02, 'weight_decay': 0.0005, 'epochs': 300, 'gpu': 0, 'use_fp16': False, 'cosineAnnealing': True, 'resume': None, 'noise_type': 'symmetric', 'openset_ratio': 0.2, 'closeset_ratio': 0.2, 'log_freq': 200, 'log_prefix': 'S2S', 'eps': 0.6, 'warmup_epochs': 10, 'fix_epoch': 20, 'tau_clean': 0.7, 'lamb_con': 0.1, 'alpha': 0.5, 'mu': 2, 'T': 10, 'lambda_e': 0.1, 'lambda_con': 1, 'lambda_id': 1.0, 'threshold': 0.02, 'with_sup': 1, 'with_e': 1, 'with_con': 1, 'with_id': 0, 'cfg_file': 'config/cifar100.cfg', 'log': 'cnn-symmetric_closeset0.2_openset0.2-S2S'}
# ...

# %%
path = '/Users/wenshuiluo/LEAP-Group/毕业设计/ablation/不同超参数/Results/cifar100'
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
fonts = FontProperties(fname = "/Library/Fonts/Arial Unicode.ttf")
plt.rcParams["font.family"] = 'Arial Unicode MS'
plt.rcParams['axes.unicode_minus']=False
plt.rcParams.update({'font.size': 25})
import os
# %matplotlib inline
import numpy as np
import json
from utils.utils import list_dir, list_files
from collections import namedtuple
param = ('lr','openset_ratio','closeset_ratio','noise_type','tau_clean', 'threshold')
param = namedtuple('param', param)
dir_list = list_dir(path)
plot_list=[]
json_list = []
for idx, dir in enumerate(dir_list):
    txt_files = list_files(os.path.join(path, dir), suffix = '.txt', prefix = True)
    json_files = list_files(os.path.join(path, dir), suffix='.json', prefix = True)
    plot_list.append(txt_files[1])
    json_list.append(json_files[0])

for index, file in enumerate(plot_list):
    num = 300
    # print(file)
    with open(json_list[index]) as f:
        json_f = json.load(f)
        print(json_f)
    print(json_f)
    with open(file) as f:
        lines = f.readlines()
    result = np.array([float(line.split('|')[3].strip().split()[-1]) for line in lines[:num]])
    x_axis = list(np.arange(1, len(lines[:num]) + 1))
    plt.figure()
    plt.plot(x_axis, result, linewidth=2.0)
    print(result[10:].mean())
print()
kwmap={}
# Out:
# {'database': 'Datasets', 'dataset': 'cifar100', 'n_classes': 100, 'rescale_size': 32, 'crop_size': 32, 'num_workers': 8, 'steps': 512, 'net': 'cnn', 'opt': 'adam', 'batch_size': 64, 'lr': 0.02, 'weight_decay': 0.0005, 'epochs': 300, 'gpu': 0, 'use_fp16': False, 'cosineAnnealing': True, 'resume': None, 'noise_type': 'symmetric', 'openset_ratio': 0.2, 'closeset_ratio': 0.2, 'log_freq': 200, 'log_prefix': 'S2S', 'eps': 0.6, 'warmup_epochs': 10, 'fix_epoch': 20, 'tau_clean': 0.7, 'lamb_con': 0.1, 'alpha': 0.5, 'mu': 2, 'T': 10, 'lambda_e': 0.5, 'lambda_con': 1, 'lambda_id': 1.0, 'threshold': 0.0, 'with_sup': 1, 'with_e': 1, 'with_con': 1, 'with_id': 1, 'cfg_file': 'config/cifar100.cfg', 'log': 'cnn-symmetric_closeset0.2_openset0.2-S2S'}
# ...

# %%
item = '/Users/wenshuiluo/LEAP-Group/experiments/毕设/Results/cifar100/03-01/wideresnet-pairflip_closeset0.4_openset0.2-S2S-20220301_155621-bestAcc_40.2125/log.txt'
# path = '/Users/wenshuiluo/LEAP-Group/experiments/毕设/ablation/不同超参数/Results/cifar100'
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
fonts = FontProperties(fname = "/Library/Fonts/Arial Unicode.ttf")
plt.rcParams["font.family"] = 'Arial Unicode MS'
plt.rcParams['axes.unicode_minus']=False
plt.rcParams.update({'font.size': 25})
import os
# %matplotlib inline
import numpy as np
import json
from utils.utils import list_dir, list_files
from collections import namedtuple
param = ('lr','openset_ratio','closeset_ratio','noise_type','tau_clean', 'threshold')
param = namedtuple('param', param)
dir_list = list_dir(path)
plot_list=[]
json_list = []
for idx, dir in enumerate(dir_list):
    txt_files = list_files(os.path.join(path, dir), suffix = '.txt', prefix = True)
    json_files = list_files(os.path.join(path, dir), suffix='.json', prefix = True)
    plot_list.append(txt_files[1])
    json_list.append(json_files[0])
plot_list=np.array([item])
for index, file in enumerate(plot_list):
    num = 300
    print(file)
   
    with open(file) as f:
        lines = f.readlines()
    result = np.array([float(line.split('|')[3].strip().split()[-1]) for line in lines[:num]])
    x_axis = list(np.arange(1, len(lines[:num]) + 1))
    plt.figure()
    plt.plot(x_axis, result, linewidth=2.0)
    print(result[10:].mean())
print()
kwmap={}
# Out:
# /Users/wenshuiluo/LEAP-Group/experiments/毕设/Results/cifar100/03-01/wideresnet-pairflip_closeset0.4_openset0.2-S2S-20220301_155621-bestAcc_40.2125/log.txt
# 37.863013793103455

# %% [markdown]
# ## 不同超参数Le、Lcon、Lid

# %%
path = '/Users/wenshuiluo/LEAP-Group/experiments/毕设/ablation/不同超参数/Results/cifar100'
import matplotlib.pyplot as plt
import os
# %matplotlib inline
import numpy as np
import json
from utils.utils import list_dir, list_files
from collections import namedtuple
param = ('openset_ratio','closeset_ratio','noise_type','lambda_e','lambda_con','lambda_id')
param = namedtuple('param', param)
dir_list = list_dir(path)
plot_list=[]
json_list = []
for idx, dir in enumerate(dir_list):
    txt_files = list_files(os.path.join(path, dir), suffix = '.txt', prefix = True)
    json_files = list_files(os.path.join(path, dir), suffix='.json', prefix = True)
    plot_list.append(txt_files[1])
    json_list.append(json_files[0])
for file in plot_list:
    print(file)
print()
kwmap={}

for index, json_file in enumerate(json_list):
    with open(json_file) as file:
        kw = json.load(file)
        kwmap[index] = param(kw['openset_ratio'],kw['closeset_ratio'],kw['noise_type'],kw['lambda_e'], \
            kw['lambda_con'],kw['lambda_id'])
        
sel = []
for key,value in kwmap.items():
    # if value.openset_ratio == 0.2 and value.closeset_ratio == 0.4:
    #     print(key)
    sel.append(key)
for item in sel:
    print(kwmap[item])
data = {}

for index, file in enumerate(plot_list):
    with open(file) as f:
        lines = f.readlines()
    # if len(lines)<100:
    #     continue
    if index not in sel:
        continue
    x_axis = list(np.arange(1, len(lines) + 1))
    result = [float(line.split('|')[3].strip().split()[-1]) for line in lines]
    mean = np.array(result)[10:].mean()
    print(mean)
    # plt.figure(figsize=(8,6))
    # plt.plot(x_axis, result)
    # plt.title(kwmap[index])
# Out:
# /Users/wenshuiluo/LEAP-Group/experiments/毕设/ablation/不同超参数/Results/cifar100/cnn-symmetric_closeset0.2_openset0.2-S2S-20220505_111523-bestAcc_62.8500/log.txt
# /Users/wenshuiluo/LEAP-Group/experiments/毕设/ablation/不同超参数/Results/cifar100/cnn-symmetric_closeset0.2_openset0.2-S2S-20220506_095911-bestAcc_60.8000/log.txt
# /Users/wenshuiluo/LEAP-Group/experiments/毕设/ablation/不同超参数/Results/cifar100/cnn-symmetric_closeset0.2_openset0.2-S2S-20220506_220526-bestAcc_63.3250/log.txt
# /Users/wenshuiluo/LEAP-Group/experiments/毕设/ablation/不同超参数/Results/cifar100/cnn-symmetric_closeset0.2_openset0.2-S2S-20220507_032035-bestAcc_63.6500/log.txt
# /Users/wenshuiluo/LEAP-Group/experiments/毕设/ablation/不同超参数/Results/cifar100/cnn-symmetric_closeset0.2_openset0.2-S2S-20220505_150345-bestAcc_63.2375/log.txt
# /Users/wenshuiluo/LEAP-Group/experiments/毕设/ablation/不同超参数/Results/cifar100/cnn-symmetric_closeset0.2_openset0.2-S2S-20220505_190324-bestAcc_60.8875/log.txt
# ...

# %%
le=[60.14, 59.90, 58.45, 59.53]
lcon=[60.07, 60.03, 60.14, 60.11]
lid = [57.39, 59.49, 60.14, 59.55]
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
fonts = FontProperties(fname = "/Library/Fonts/Arial Unicode.ttf")
plt.rcParams["font.family"] = 'Arial Unicode MS'
plt.rcParams['axes.unicode_minus']=False
plt.rcParams.update({'font.size': 25})
import os
# %matplotlib inline
import numpy as np
labels=['$\lambda_{e}$','$\lambda_{con}$','$\lambda_{id}$']
x_axis = [0.1,0.5,1.0,2.0]
x=[1,2,3,4]
plt.figure(figsize=(8,5),dpi=100)
plt.plot(x,le,marker='*',linewidth=2.0)
plt.plot(x,lcon,marker='s', linewidth=2.0)
plt.plot(x,lid,marker='^',linewidth=2.0)

plt.scatter([1.0, 3.0], [60.14,60.14],marker='o', facecolors='white', edgecolors='r',lw=2,s=200)
plt.xticks(x,x_axis)
plt.legend(labels)
font_s=16
plt.xlabel('超参数值',fontsize=font_s)
plt.ylim(55,61)
plt.ylabel('分类准确率',fontsize=font_s)
plt.grid(linewidth=0.4)

# %% [markdown]
# ## 不同网络架构

# %%
path ='/Users/wenshuiluo/LEAP-Group/experiments/毕设/ablation/不同架构'
import matplotlib.pyplot as plt
import os
# %matplotlib inline
import numpy as np
import json
from utils.utils import list_dir, list_files
from collections import namedtuple
param = ('openset_ratio','closeset_ratio','noise_type','net')
param = namedtuple('param', param)
dir_list = list_dir(path)
plot_list=[]
json_list = []
for idx, dir in enumerate(dir_list):
    txt_files = list_files(os.path.join(path, dir), suffix = '.txt', prefix = True)
    json_files = list_files(os.path.join(path, dir), suffix='.json', prefix = True)
    plot_list.append(txt_files[1])
    json_list.append(json_files[0])
for file in plot_list:
    print(file)
print()
kwmap={}

for index, json_file in enumerate(json_list):
    with open(json_file) as file:
        kw = json.load(file)
        kwmap[index] = param(kw['openset_ratio'],kw['closeset_ratio'],kw['noise_type'],kw['net'])
        
sel = [0,1,2,3]
# for key,value in kwmap.items():
#     # if value.openset_ratio == 0.2 and value.closeset_ratio == 0.4:
#     #     print(key)
#     sel.append(key)
for item in sel:
    print(kwmap[item])
data = {}
plt.figure(figsize=(8,6))
times = []
for index, file in enumerate(plot_list):
    num = 200
    with open(file) as f:
        lines = f.readlines()
    # if len(lines)<100:
    #     continue
    if index not in sel:
        continue
    x_axis = list(np.arange(1, len(lines) + 1))
    result = [float(line.split('|')[3].strip().split()[-1]) for line in lines]
    time = np.array([float(line.split('|')[2].strip().split()[-2]) for line in lines] )
    times.append(time.mean() * 200 / 3600)
    mean = np.array(result)[10:].mean()
    print(mean)
    print(f'time_mean:{time.mean() * 200 / 3600 :.2f}')
    
    plt.plot(x_axis, result)
    plt.title(kwmap[index])
    
print(np.array(times).mean())
# Out:
# /Users/wenshuiluo/LEAP-Group/experiments/毕设/ablation/不同架构/resnet18-symmetric_closeset0.2_openset0.2-S2S-20220507_164232-bestAcc_69.6375/log.txt
# /Users/wenshuiluo/LEAP-Group/experiments/毕设/ablation/不同架构/wideresnet-symmetric_closeset0.2_openset0.2-S2S-20220506_095944-bestAcc_65.900/log.txt
# /Users/wenshuiluo/LEAP-Group/experiments/毕设/ablation/不同架构/resnet18-symmetric_closeset0.2_openset0.2-S2S-20220507_121620-bestAcc_65.2750/log.txt
# /Users/wenshuiluo/LEAP-Group/experiments/毕设/ablation/不同架构/preactresnet-symmetric_closeset0.2_openset0.2-S2S-20220506_231250-bestAcc_65.6250/log.txt
#
# param(openset_ratio=0.2, closeset_ratio=0.2, noise_type='symmetric', net='resnet18')
# param(openset_ratio=0.2, closeset_ratio=0.2, noise_type='symmetric', net='wideresnet')
# param(openset_ratio=0.2, closeset_ratio=0.2, noise_type='symmetric', net='resnet18')
# param(openset_ratio=0.2, closeset_ratio=0.2, noise_type='symmetric', net='preactresnet')
# 67.35116315789473
# time_mean:4.36
# ...
